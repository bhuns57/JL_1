# %% [markdown]
# # **Selecting attributes via inheratance**

# %% [markdown]
# ## Copilot Starter

# %% [markdown]
# ### Inheritance-Based Classification Scaffold
# **🔧 Base Class: CompoundBase**

# %%
class CompoundBase:
    def __init__(self, gsn, name, dose=None, flags=None):
        self.gsn = gsn
        self.name = name
        self.dose = dose
        self.flags = flags or []

    def describe(self):
        return f"{self.name} (GSN: {self.gsn}) — Dose: {self.dose} mg"

# Generation subclasses
class Generation1(CompoundBase):
    def __init__(self, gsn, name, dose=None, flags=None):
        super().__init__(gsn, name, dose, flags)
        self.level = 1

class Generation2(CompoundBase):
    def __init__(self, gsn, name, dose=None, flags=None):
        super().__init__(gsn, name, dose, flags)
        self.level = 2

class Generation3(CompoundBase):
    def __init__(self, gsn, name, dose=None, flags=None):
        super().__init__(gsn, name, dose, flags)
        self.level = 3

class Generation4(CompoundBase):
    def __init__(self, gsn, name, dose=None, flags=None):
        super().__init__(gsn, name, dose, flags)
        self.level = 4

class Generation5(CompoundBase):
    def __init__(self, gsn, name, dose=None, flags=None):
        super().__init__(gsn, name, dose, flags)
        self.level = 5

# %% [markdown]
# ### 🌿 Subclass Example: Generation1, Generation2, etc.

# %%
class Generation1(CompoundBase):
    def __init__(self, gsn, name, dose=None, flags=None):
        super().__init__(gsn, name, dose, flags)
        self.level = 1

class Generation2(Generation1):
    def __init__(self, gsn, name, dose=None, flags=None):
        super().__init__(gsn, name, dose, flags)
        self.level = 2

# %% [markdown]
# ### 🧪 Instantiate a Full Lineage

# %%
g5 = Generation5("05", "CoQ10", dose=100)
g4 = Generation4("04", "MitoSupport")
g3 = Generation3("03", "Energy")
g2 = Generation2("02", "Metabolic")
g1 = Generation1("01", "Health")

lineage = [g1, g2, g3, g4, g5]
id10 = ''.join([node.gsn for node in lineage])
print("ID10:", id10)
# Out:
# ID10: 0102030405

# %%
lineage

# %% [markdown]
# ![image.png](attachment:37704b40-b18d-4b76-8c80-5c3843b34e13.png)
