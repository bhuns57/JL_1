# %%
import os

# List of files Git warned would be overwritten
files_to_delete = [
    ".gitignore", "1RatLabs.ipynb", "1RatLabsv2.ipynb", "1RatLabsv3.ipynb",
    "1ratlabs_toc.ipynb", "970init.ipynb", "Class_based_loader.ipynb",
    "Cls_attrbt_tbl.csv", "Copilot Template.ipynb", "Diagrarm_adders.ipynb",
    "F_input_def_sb.ipynb", "Function registry.ipynb", "JL_z_files/step_by_step_csv-Copy1.ipynb",
    "JL_z_files/step_by_step_csv1sav.ipynb", "JL_z_files/step_step_file_utils.ipynb",
    "L_JL_Hlp.ipynb", "L_WSL_JL_hlp.ipynb", "L_medical.ipynb", "L_pilot_classTOplot.ipynb",
    "SBblend_addinto_mstr.ipynb", "Sandbox_load.ipynb", "Step-by-Step Build Plan.ipynb",
    "Step-by-Step Build.ipynb", "Txl_dtv.csv", "ad_sn_cls.csv", "ad_sn_log.csv",
    "ad_v1.ipynb", "atrbt_inhrtnce.ipynb", "bld_init.ipynb", "bld_init.txt",
    "class Inheritance.ipynb", "class_dict_grp_plan.ipynb", "combing_new.ipynb",
    "copilot_fnctns_folder/L_Quotes.ipynb", "copilot_fnctns_folder/xl_xf_xl.ipynb",
    "copilot_inbody.ipynb", "copliot pages.ipynb", "csv_sys_fnct.ipynb", "df_nm.csv",
    "dt_clms.csv", "dtv_ubn_snb.csv", "file_utils.py", "glucose to 08212025.csv",
    "grp_creation_tkinter.ipynb", "mrn_mstr_8_04.csv", "named NumPy array, stored in a dictionary.ipynb",
    "prvn_fnctns.ipynb", "reference_linking.ipynb", "step_by_step_csv.ipynb",
    "sys_util/Restore_extensions.ipynb", "sys_util/Sys_utils.ipynb", "sys_util/cleanJL.ipynb",
    "tkiner.ipynb", "xl_ada.csv"
]

def safe_delete(base_path="."):
    for f in files_to_delete:
        full_path = os.path.join(base_path, f)
        try:
            if os.path.isfile(full_path):
                os.remove(full_path)
                print(f"🗑️ Deleted file: {full_path}")
            elif os.path.isdir(full_path):
                os.rmdir(full_path)
                print(f"🗑️ Deleted folder: {full_path}")
        except Exception as e:
            print(f"⚠️ Could not delete {full_path}: {e}")

# Run cleanup
safe_delete()
# Out:
# 🗑️ Deleted file: ./.gitignore
# 🗑️ Deleted file: ./1RatLabs.ipynb
# 🗑️ Deleted file: ./1RatLabsv2.ipynb
# 🗑️ Deleted file: ./1RatLabsv3.ipynb
# 🗑️ Deleted file: ./1ratlabs_toc.ipynb
# 🗑️ Deleted file: ./970init.ipynb
# 🗑️ Deleted file: ./Class_based_loader.ipynb
# 🗑️ Deleted file: ./Cls_attrbt_tbl.csv
# 🗑️ Deleted file: ./Copilot Template.ipynb
# 🗑️ Deleted file: ./Diagrarm_adders.ipynb
# 🗑️ Deleted file: ./F_input_def_sb.ipynb
# 🗑️ Deleted file: ./Function registry.ipynb
# 🗑️ Deleted file: ./JL_z_files/step_by_step_csv-Copy1.ipynb
# 🗑️ Deleted file: ./JL_z_files/step_by_step_csv1sav.ipynb
# 🗑️ Deleted file: ./JL_z_files/step_step_file_utils.ipynb
# 🗑️ Deleted file: ./L_JL_Hlp.ipynb
# 🗑️ Deleted file: ./L_WSL_JL_hlp.ipynb
# 🗑️ Deleted file: ./L_medical.ipynb
# 🗑️ Deleted file: ./L_pilot_classTOplot.ipynb
# 🗑️ Deleted file: ./SBblend_addinto_mstr.ipynb
# 🗑️ Deleted file: ./Sandbox_load.ipynb
# 🗑️ Deleted file: ./Step-by-Step Build Plan.ipynb
# ...
