# %% [markdown]
# # Introducing Diagrams to JL

# %% [markdown]
# ## Choosing first generation app.

# %% [markdown]
# ### Refernce List [JL_wb:***ad_v1***][Reference and Help:**JupyterLab is a great sandbox for building and visualizing hierarchical structures **]

# %% [markdown]
# ***"JupyterLab is a great sandbox for building and visualizing hierarchical structures like ancestral trees, signal pathways, and organizational charts"***

# %% [markdown]
# ### Scaffold

# %%
import sys
print(sys.executable)     #/home/bhuns/miniconda3/envs/scu/bin/python
# Out:
# /home/bhuns/miniconda3/envs/scu/bin/python

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes
nodes = ["ad_an", "raw_storage", "classified_instances", "instance_001", "instance_002"]
G.add_nodes_from(nodes)

# Add edges to represent relationships
edges = [
    ("ad_an", "raw_storage"),
    ("ad_an", "classified_instances"),
    ("classified_instances", "instance_001"),
    ("classified_instances", "instance_002")
]
G.add_edges_from(edges)

# Define node positions for better layout
pos = {
    "ad_an": (0, 2),
    "raw_storage": (-1, 1),
    "classified_instances": (1, 1),
    "instance_001": (0.5, 0),
    "instance_002": (1.5, 0)
}

# Set up plot with constrained layout
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots(figsize=(8, 6), constrained_layout=True)

# Draw the graph
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=2000, font_size=10, font_weight='bold', edge_color='gray', ax=ax)

# Annotate for extensibility
ax.text(-1.5, 2.2, "Hooks for operator overlays", fontsize=9, color='darkgreen')
ax.text(-1.5, 2.0, "Future migration to Plotly supported", fontsize=9, color='darkgreen')

# Save the diagram
output_path = "png/ad_an_structure_diagram.png"
plt.savefig(output_path)
print(f"Diagram saved to {output_path}")
# Out:
# Diagram saved to png/ad_an_structure_diagram.png

# %% [markdown]
# ### Scaffold

# %% [markdown]
# # Introducing Diagrams to JL
